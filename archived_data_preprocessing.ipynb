# %%
#mounting drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
# reading archived data 
from os import read
df = pd.read_csv('/content/drive/MyDrive/DB project/nyt-metadata.csv')
# Out:
# <ipython-input-6-833f33f70d18>:2: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/drive/MyDrive/DB project/nyt-metadata.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2187527 entries, 0 to 2187526
# Data columns (total 20 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   abstract          object
#  1   web_url           object
#  2   snippet           object
#  3   lead_paragraph    object
#  4   print_section     object
#  5   print_page        object
#  6   source            object
#  7   multimedia        object
#  8   headline          object
#  9   keywords          object
#  10  pub_date          object
#  11  document_type     object
#  12  news_desk         object
#  13  section_name      object
#  14  byline            object
#  15  type_of_material  object
#  16  _id               object
#  17  word_count        float64
#  18  uri               object
#  19  subsection_name   object
# dtypes: float64(1), object(19)
# memory usage: 333.8+ MB

# %%
df.head(100)
# Out:
#                                              abstract  \
# 0   Article on upcoming New York Giants-Dallas Cow...
# 1   Jeanne C Pond letter expresses hope that spiri...
# 2   Many experts on Y2K computer problem report th...
# 3   WILL the forces of globalism continue to push ...
# 4    SPECIAL TODAY  The Millennium  Envisioning th...
# ..                                                ...
# 95  Despite a few sputters and glitches, the world...
# 96  TAYLOR-Frieda. The partners and staff of Lipsk...
# 97  FOLEY-Bill. One great guy who truly loved and ...
# 98   Russian Stocks Leap After Yeltsin Steps Aside...
# 99  Anne Lord Witt letter, replying to Joyce Carol...
#
#                                               web_url  \
# 0   https://www.nytimes.com/2000/01/01/sports/pro-...
# 1   https://www.nytimes.com/2000/01/01/opinion/l-o...
# 2   https://www.nytimes.com/2000/01/01/us/1-1-00-t...
# 3   https://www.nytimes.com/2000/01/01/news/vision...
# ...

# %%
df.isnull().sum()
# Out:
# abstract              31917
# web_url                   1
# snippet              196164
# lead_paragraph        41977
# print_section        744553
# print_page           745798
# source                    1
# multimedia                1
# headline                  1
# keywords                  1
# pub_date                  1
# document_type             1
# news_desk            301163
# section_name           2009
# byline                    1
# type_of_material      85280
# _id                       1
# word_count                2
# uri                       2
# subsection_name     1600888
# dtype: int64

# %%
#dropping rows with missing values
cleaned_data = df.dropna()

# %%
cleaned_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 369300 entries, 83 to 2187520
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   abstract          369300 non-null  object
#  1   web_url           369300 non-null  object
#  2   snippet           369300 non-null  object
#  3   lead_paragraph    369300 non-null  object
#  4   print_section     369300 non-null  object
#  5   print_page        369300 non-null  object
#  6   source            369300 non-null  object
#  7   multimedia        369300 non-null  object
#  8   headline          369300 non-null  object
#  9   keywords          369300 non-null  object
#  10  pub_date          369300 non-null  object
#  11  document_type     369300 non-null  object
#  12  news_desk         369300 non-null  object
#  13  section_name      369300 non-null  object
#  14  byline            369300 non-null  object
#  15  type_of_material  369300 non-null  object
# ...

# %%
cleaned_data.isnull().sum()
# Out:
# abstract            0
# web_url             0
# snippet             0
# lead_paragraph      0
# print_section       0
# print_page          0
# source              0
# multimedia          0
# headline            0
# keywords            0
# pub_date            0
# document_type       0
# news_desk           0
# section_name        0
# byline              0
# type_of_material    0
# _id                 0
# word_count          0
# uri                 0
# subsection_name     0
# dtype: int64

# %%
cleaned_data.head(100)
# Out:
#                                                 abstract  \
# 83     Gholam-Reza Hassani, the most conservative voi...
# 243    R W Apple Jr article on the prospects for Amer...
# 269    Article on Jonathan's Dream, fully-accessible ...
# 355    June Pusbach O'Neill discusses her book The Gr...
# 438    Interview with June Pusbach O'Neill, author of...
# ...                                                  ...
# 12101  Four-hour CBS mini-series, Sally Hemings: An A...
# 12153  Barbara Kessel essay describes how otherwise b...
# 12624  John A Cutter article on new retiree Joe Volz,...
# 13603                                 Books in Brief: SA
# 13616  THE silent opening images of Eric Mendelsohn's...
#
#                                                  web_url  \
# 83     https://www.nytimes.com/2000/01/01/washington/...
# 243    https://www.nytimes.com/2000/01/01/washington/...
# 269    https://www.nytimes.com/2000/01/02/nyregion/a-...
# ...

# %%
# Filterig the DataFrame based on the word 'politics' in subsection column

# Specifying subsection name 'column_name'
filtered_df = df[df['subsection_name'].str.contains('politics', case=False, na=False)]

# Displaying the filtered DataFrame
filtered_df.head()
# Out:
#                                                 abstract  \
# 83     Gholam-Reza Hassani, the most conservative voi...
# 243    R W Apple Jr article on the prospects for Amer...
# 32305  Greg Zeigerson letter says escapee from Cuba, ...
# 32365  Cuban-Americans living in Miami who have dissi...
# 49329                                WASHINGTON, June 28
#
#                                                  web_url  \
# 83     https://www.nytimes.com/2000/01/01/washington/...
# 243    https://www.nytimes.com/2000/01/01/washington/...
# 32305  https://www.nytimes.com/2000/04/28/classified/...
# 32365  https://www.nytimes.com/2000/04/28/classified/...
# 49329  https://www.nytimes.com/2000/06/29/washington/...
#
#                                                  snippet  \
# 83     Gholam-Reza Hassani, the most conservative voi...
# 243    R W Apple Jr article on the prospects for Amer...
# 32305  Greg Zeigerson letter says escapee from Cuba, ...
# ...

# %%
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 83393 entries, 83 to 2187482
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   abstract          83351 non-null  object
#  1   web_url           83393 non-null  object
#  2   snippet           82069 non-null  object
#  3   lead_paragraph    82724 non-null  object
#  4   print_section     40872 non-null  object
#  5   print_page        40849 non-null  object
#  6   source            83393 non-null  object
#  7   multimedia        83393 non-null  object
#  8   headline          83393 non-null  object
#  9   keywords          83393 non-null  object
#  10  pub_date          83393 non-null  object
#  11  document_type     83393 non-null  object
#  12  news_desk         69131 non-null  object
#  13  section_name      83393 non-null  object
#  14  byline            83393 non-null  object
#  15  type_of_material  78894 non-null  object
# ...

# %%
#saving the archived_data file 
filtered_df.to_csv('/content/drive/MyDrive/DB project/archived_data.csv', index=False)
